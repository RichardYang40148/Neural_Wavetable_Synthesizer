# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from magenta.models.nsynth import utils
from magenta.models.nsynth.wavenet import fastgen
from IPython.display import Audio
# %matplotlib inline
# %config InlineBackend.figure_format = 'jpg'

# %%
audio = utils.load_audio('gen_wavetable_sine', sample_length=512, sr=16000)

# %%
print audio.shape
# Out:
# (512,)

# %%
x = np.linspace(-np.pi, np.pi, 512)
plt.plot(audio)
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.axis('tight')

plt.show()

# %%
audio = utils.load_audio('gen_wavetable_tri', sample_length=512, sr=16000)

# %%
x = np.linspace(-np.pi, np.pi, 512)
plt.plot(audio)
#plt.xlabel('Angle [rad]')
#plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %%
audio = utils.load_audio('gen_wavetable_saw', sample_length=512, sr=16000)

# %%
plt.plot(audio)
#plt.xlabel('Angle [rad]')
#plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %%
audio = utils.load_audio('gen_wavetable_sawsin_int', sample_length=512, sr=16000)

# %%
plt.plot(audio)
#plt.xlabel('Angle [rad]')
#plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()
